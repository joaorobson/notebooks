# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %% [markdown]
# ## Jordan vs LeBron vs Kobe
# ### **Introdução**
# Muitos apesctos devem ser levados em conta para determinar o maior atleta de todos os tempos em qualquer modalidade. No contexto de esportes coletivos, a avalição se torna ainda mais complexa pelo simples fato dessas atividades demandarem mais de um indíviduo por time para haver uma disputa e os rendimentos individuais de qualquer atleta serem influenciados positiva e/ou negativamente de acordo com o desempenho de seus companheiros. Outras questões como a época em que o jogador jogou ou em qual local tem forte influência em suas estatísticas.
#
# Jogadores de épocas diferentes, por exemplo, muitas vezes são incoparáveis tanto por conta da evolução da condição física no esporte quanto por conta de mudanças nas regras e táticas/estilo de jogo.
#
# Um atleta que já é naturalmente superior em uma liga competitiva, ao se transferir para uma liga com um nível técnico mais baixo ou até jogar em um time com investimento e/ou um elenco muito superior aos demais provavelmente terá números superiores.
#
# Esses e outros aspectos externos existem e caso não sejam levados em conta, podem tendeciar a decisão de um ranking.
#
# Apesar disso tudo, o que é indiscutível, não só no mundo dos esportes, são dados. Números não mentem. A análise a seguir será exclusivamente baseada em estatísticas para determinar o maior jogador de basquete de todos os tempos.
#
# Felizmente, alguns dos aspectos externos citados anteriormente que são difíceis de quantificar tem uma influência pequena nesta análise. O temporal, por exemplo, apesar de existir, impacta pouco. Jordan disputou 4 temporadas em que Kobe já jogava. Kobe e Lebron diviram os holofotes da NBA por 13 anos. Além disso, os 3 jogaram por times competitivos da NBA, como mostram o número de títulos de cada um. Apesar de outros pontos influenciarem no rendimento de cada um (lesões, por exemplo), eles serão deixados de lado para simplificar a análise.
#
# #### **Cálculo da nota final**
#
# Para determinar "o maior de todos os tempos", uma nota será dada para cada um a fim de indicar objetivamente o melhor dos 3.
#
# O cálculo será divido em três partes: títulos, que são uma medida bastante simples do impacto coletivo de cada jogador; prêmios individuais, medindo o impacto individual; e estatísticas individuais, que servem como indicador primário da capacidade de cada um de dominar o jogo em aspectos ofensivos e defensivos.
#
# Para calcular o valor final, cada parte tem um peso. Os títulos representarão 20% da nota, pois, como dito anteriormente, tem uma dependência muito grande do aspecto coletivo do jogo; prêmios individuais, 15%; e as estatísticas em si, 75%, pois são a forma mais objetiva de avaliar a capacidade de cada um e não dependem de nehuma forma de avaliação subjetiva para serem atribuídas, diferentemente dos prêmios indiviuais.
#
# Para cada tópico avaliado em cada parte, um determinado número de pontos serão distribuídos, de acordo com a classificação de cada um no critério avalidado.
#
# Para os títulos, serão 10 pontos para o primeiro colocado, 7 para o segundo e 4 para o terceiro.
#
# Para os prêmios, serão 3 pontos paro o primeiro colocado, 2 para o segundo e 1 para o terceiro.
#
# Para as estatísticas, para a análise de total, total por jogo e total por temporada, o primeiro colocado recebe 15 pontos, o segundo 10 e o terceiro 5. Para as duas métricas de presença no Top 5, 5 pontos serão dados para o primeiro, 4 para o segundo e assim sucessivamente.
#
# Em caso de empate, a nota mais alta entre os empatados será dada.
#
# Ao final, a soma dos pontos de cada estatística serão somados e dividos por 5. Esse resultado somado com os pontos recebidos por prêmios e títulos dará uma nota entre 28 e 100 para cada jogador e por meio dela será decidido quem foi o maior de todos os tempos.

# %%
jordan_total_points = 0
kobe_total_points = 0
lebron_total_points = 0

# %% [markdown]
# ### Títulos

# %% [markdown]
# O basquete é um esporte coletivo e, como em qualquer esporte coletivo, quem ganha e perde campeonatos é um time, por melhor que seja o craque (ou os craques) do time. Os maiores da história não ganharam sozinhos.
# Apesar disso, muitos grandes atletas possuem poucas (ou nenhuma) consquistas grandiosas. Isso ocorre por diversos motivos. Uns não conseguem por lesões. Outros por não ter um elenco ao seu lado capaz de ser competitivo. Mesmo assim, todo time com um jogador muito acima da média, independente da modalidade, tende a tirar proveito dessa superiodade e associá-la com o aspecto coletivo a fim de conquistar títulos. Nessa seção, o número de títulos de cada um dos três será analisado.

# %%
jordan_titles_points = 0
kobe_titles_points = 0
lebron_titles_points = 0

# %% [markdown]
# #### Títulos da NBA

# %%
jordan_nba_titles = 6
kobe_nba_titles = 5
lebron_nba_titles = 3

# %%
jordan_titles_points += 10
kobe_titles_points += 7
lebron_titles_points += 4

# %% [markdown]
# #### Títulos olímpicos

# %%
jordan_olympic_medals = {'ouros': 2}
kobe_olympic_medals = {'ouros': 2}
lebron_olympic_medals = {'ouros': 2, 'bronze':1}

# %%
jordan_titles_points += 7
kobe_titles_points += 7
lebron_titles_points += 10

# %% [markdown]
# ### Prêmios individuais

# %%
jordan_ind_awards_points = 0
kobe_ind_awards_points = 0
lebron_ind_awards_points = 0

# %% [markdown]
# #### MVP (Jogador mais valioso) da NBA

# %%
jordan_mvps = 5
kobe_mvps = 1
lebron_mvps = 4

# %%
jordan_ind_awards_points += 3
kobe_ind_awards_points += 1
lebron_ind_awards_points += 2

# %% [markdown]
# #### MVP das Finais da NBA

# %%
jordan_finals_mvps = 6
kobe_finals_mvps = 2
lebron_finals_mvps = 3

# %%
jordan_ind_awards_points += 3
kobe_ind_awards_points += 1
lebron_ind_awards_points += 2

# %% [markdown]
# #### Seleções para Jogos das estrelas

# %%
jordan_all_star_games = 14
kobe_all_star_games = 18
lebron_all_star_games = 16

# %%
jordan_ind_awards_points += 1
kobe_ind_awards_points += 3
lebron_ind_awards_points += 2

# %% [markdown]
# #### Seleções para o melhor quinteto (All-NBA)

# %%
jordan_all_nba = {'primeiro_time': 10, 'segundo_time': 1, 'terceiro_time': 0}
kobe_all_nba = {'primeiro_time': 11, 'segundo_time': 2, 'terceiro_time': 2}
lebron_all_nba = {'primeiro_time': 12, 'segundo_time': 2, 'terceiro_time': 1}

# %%
# Lebron foi escolhido 15 vezes para o melhor quinteto, assim como Kobe. Mas uma vez a mais para o primeiro time.
# Aqui, esse ponto será usado como critério de desempate.
jordan_ind_awards_points += 1
kobe_ind_awards_points += 2
lebron_ind_awards_points += 3

# %% [markdown]
# #### Seleções para o melhor quinteto defensivo (NBA All-Defensive Team)

# %%
jordan_all_def = {'primeiro_time': 9, 'segundo_time': 0}
kobe_all_def = {'primeiro_time': 9, 'segundo_time': 3}
lebron_all_def = {'primeiro_time': 5, 'segundo_time': 1}

# %%
jordan_ind_awards_points += 2
kobe_ind_awards_points += 3
lebron_ind_awards_points += 1

# %% [markdown]
# ### Estatísticas individuais
#
# A avaliação das estatíticas individuais tem o foco em cinco aspectos fundamentais para um jogador de basquete completo: arremesso (pontuação e precisão), assistências, rebotes ofensivos e defensivos e turnovers (erros que custam a posse de bola). Por meio desses 5 pontos, pode-se ter noção e avaliar o desempenho de cada atleta tanto no ataque, pontuando, servindo os companheiros de equipe e recuperando rebotes, tudo isso sem cometer error que custem a posse de bola para o time, quanto na defesa, com rebotes defensivos.
#
# Cada um dos 5 pontos terão estatísticas específicas a serem analisadas. São elas:
# * Arremesso: Total de pontos;
# * Assistências: Total de assistências;
# * Rebotes ofensivos: Total de rebotes ofensivos;
# * Rebotes defensivos: Total de rebotes defensivos;
# * Turnoves: Total de turnoves.
#
# Para cada uma das 5 estatísticas, 5 medidas serão analisadas, visando avaliar não só os picos de performance, mas a consistência ao longo dos anos também:
# * Total
# * Média por jogo;
# * Média por temporada;
# * Presença no Top 5 geral no total por temporada;
# * Presença no Top 5 geral na média por jogo por temporada.
#
# No caso dos turnovers, a regra seguirá a mesma lógica, mas com a pontuação dada de maneira invertida.
#
# A fonte de todos os dados é do site [Basketball Reference](https://www.basketball-reference.com/)

# %%
top_5_points = list(range(1, 6))[::-1]
top_5_points_mapping = {i:top_5_points[i] for i in range(5)}

# %%
top_5_points_mapping
# Out:
# {0: 5, 1: 4, 2: 3, 3: 2, 4: 1}

# %%
# csv's retirados de https://www.basketball-reference.com/

jordan_career = pd.read_csv('https://raw.githubusercontent.com/joaorobson/data_science/master/jordan_vs_kobe_vs_lebron/jordan_career.csv')
kobe_career = pd.read_csv('https://raw.githubusercontent.com/joaorobson/data_science/master/jordan_vs_kobe_vs_lebron/kobe_career.csv')
lebron_career = pd.read_csv('https://raw.githubusercontent.com/joaorobson/data_science/master/jordan_vs_kobe_vs_lebron/lebron_career.csv')

# %%
jordan_stats_points = 0
kobe_stats_points = 0
lebron_stats_points = 0

# %% [markdown]
# #### Total de temporadas jogadas

# %%
jordan_total_seasons = len(jordan_career)
kobe_total_seasons = len(kobe_career)
lebron_total_seasons = len(lebron_career)

# %%
print('Temporadas disputadas\n')

print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_seasons,
    kobe_total_seasons,
    lebron_total_seasons,
))
# Out:
# Temporadas disputadas
#
# Jordan: 15
# Kobe: 20
# Lebron: 17

# %% [markdown]
# #### Total de jogos na carreira

# %%
jordan_total_games = jordan_career['G'].sum()
kobe_total_games = kobe_career['G'].sum()
lebron_total_games = lebron_career['G'].sum()

# %%
print('Jogos disputados\n')

print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_games,
    kobe_total_games,
    lebron_total_games,
))
# Out:
# Jogos disputados
#
# Jordan: 1072
# Kobe: 1346
# Lebron: 1247

# %% [markdown]
# #### Média de jogos por temporada regular

# %%
print('Média de jogos por temporada regular\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_games/jordan_total_seasons,
    kobe_total_games/kobe_total_seasons,
    lebron_total_games/lebron_total_seasons,
))
# Out:
# Média de jogos por temporada regular
#
# Jordan: 71.46666666666667
# Kobe: 67.3
# Lebron: 73.3529411764706

# %% [markdown]
# #### Arremesso

# %% [markdown]
# ##### Total de pontos na carreira em temporada regular (NBA)

# %%
jordan_total_points = jordan_career['PTS'].sum()
kobe_total_points = kobe_career['PTS'].sum()
lebron_total_points = lebron_career['PTS'].sum()

# %%
print('Total de pontos na carreira\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_points,
    kobe_total_points,
    lebron_total_points,
))
# Out:
# Total de pontos na carreira
#
# Jordan: 32292
# Kobe: 33643
# Lebron: 33768

# %%
jordan_stats_points += 5
kobe_stats_points += 10
lebron_stats_points += 15

# %% [markdown]
# ##### Média de pontos por jogo

# %%
print('Média de pontos por jogo\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_points/jordan_total_games,
    kobe_total_points/kobe_total_games,
    lebron_total_points/lebron_total_games,
))
# Out:
# Média de pontos por jogo
#
# Jordan: 30.12313432835821
# Kobe: 24.994799405646358
# Lebron: 27.079390537289495

# %%
jordan_stats_points += 15
kobe_stats_points += 5
lebron_stats_points += 10

# %% [markdown]
# ##### Média de pontos por temporada regular

# %%
print('Média de pontos por temporada\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_points/jordan_total_seasons,
    kobe_total_points/kobe_total_seasons,
    lebron_total_points/lebron_total_seasons,
))
# Out:
# Média de pontos por temporada
#
# Jordan: 2152.8
# Kobe: 1682.15
# Lebron: 1986.3529411764705

# %%
jordan_stats_points += 15
kobe_stats_points += 5
lebron_stats_points += 10

# %% [markdown]
# ##### Total de pontos por temporada

# %%
plt.figure(figsize=(10,10))
max_years = max([len(jordan_career), len(kobe_career), len(lebron_career)])
years = ['{}º ano'.format(i) for i in range(1, max_years+1)]
plt.xticks(list(range(max_years)),years, fontsize=14, rotation=90)

j, = plt.plot(jordan_career['PTS'])
k, = plt.plot(kobe_career['PTS'])
l, = plt.plot(lebron_career['PTS'])
plt.title('Pontos por temporada')
plt.xlabel('Ano na carreira')
plt.ylabel('Pontos')
plt.legend([j,k,l], ('Jordan', 'Kobe', 'Lebron'))
plt.show()

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

jordan_career_points = pd.DataFrame(jordan_career['PTS'])
jordan_career_points['name'] = 'jordan'
kobe_career_points = pd.DataFrame(kobe_career['PTS'])
kobe_career_points['name'] = 'kobe'
lebron_career_points = pd.DataFrame(lebron_career['PTS'])
lebron_career_points['name'] = 'lebron'
per_career_points = pd.concat([jordan_career_points, kobe_career_points, lebron_career_points])
sorted_per_career_points =  per_career_points.sort_values('PTS', ascending=False)
colors = []
for _, i in sorted_per_career_points.iterrows():
  if i['name'] == 'jordan':
    colors.append('r')
  elif i['name'] == 'kobe':
    colors.append('g')
  else:
    colors.append('b')
plt.figure(figsize=(10,10))
plt.title('Pontos por temporada')
plt.ylabel('Pontos')
plt.xticks([i for i in range(0, len(per_career_points), 5)])
plt.bar([i for i in range(len(per_career_points))], sorted_per_career_points['PTS'], color=colors)


legend_elements = [Line2D([0], [0], color='r', lw=4, label='Jordan'),
                   Line2D([0], [0], color='g', lw=4, label='Kobe'),
                   Line2D([0], [0], color='b', lw=4, label='Lebron')]

plt.legend(handles=legend_elements, loc=1)
plt.show()

# %%
top_5_points_per_season = sorted_per_career_points[:5].reset_index(drop=True)
top_5_points_per_season
# Out:
#     PTS    name
# 0  3041  jordan
# 1  2868  jordan
# 2  2832    kobe
# 3  2753  jordan
# 4  2633  jordan

# %%
jordan_pps_pos = top_5_points_per_season[top_5_points_per_season.name == 'jordan'].index
kobe_pps_pos = top_5_points_per_season[top_5_points_per_season.name == 'kobe'].index
lebron_pps_pos = top_5_points_per_season[top_5_points_per_season.name == 'lebron'].index

# %%
jordan_stats_points += sum({i:top_5_points_mapping[i] for i in jordan_pps_pos}.values())
kobe_stats_points += sum({i:top_5_points_mapping[i] for i in kobe_pps_pos}.values())
lebron_stats_points += sum({i:top_5_points_mapping[i] for i in lebron_pps_pos}.values())

# %% [markdown]
# ##### Média de pontos por jogo por temporada

# %%
plt.figure(figsize=(10,10))
max_years = max([len(jordan_career), len(kobe_career), len(lebron_career)])
years = ['{}º ano'.format(i) for i in range(1, max_years+1)]
plt.xticks(list(range(max_years)),years, fontsize=14, rotation=90)

j, = plt.plot(jordan_career['PTS']/jordan_career['G'])
k, = plt.plot(kobe_career['PTS']/kobe_career['G'])
l, = plt.plot(lebron_career['PTS']/lebron_career['G'])
plt.title('Média de pontos por jogo por temporada')
plt.xlabel('Ano na carreira')
plt.ylabel('Média de pontos por jogo')
plt.legend([j,k,l], ('Jordan', 'Kobe', 'Lebron'))
plt.show()

# %%
jordan_career_points_avg = pd.DataFrame({'AVG': jordan_career['PTS']/jordan_career['G']})
jordan_career_points_avg['name'] = 'jordan'
kobe_career_points_avg = pd.DataFrame({'AVG':kobe_career['PTS']/kobe_career['G']})
kobe_career_points_avg['name'] = 'kobe'
lebron_career_points_avg = pd.DataFrame({'AVG':lebron_career['PTS']/lebron_career['G']})
lebron_career_points_avg['name'] = 'lebron'
per_career_points_avg = pd.concat([jordan_career_points_avg, kobe_career_points_avg, lebron_career_points_avg])
sorted_per_career_points_avg =  per_career_points_avg.sort_values('AVG', ascending=False)
colors = []
for _, i in sorted_per_career_points_avg.iterrows():
    if i['name'] == 'jordan':
        colors.append('r')
    elif i['name'] == 'kobe':
        colors.append('g')
    else:
        colors.append('b')
plt.figure(figsize=(10,10))
plt.title('Média de pontos por jogo por temporada')
plt.ylabel('Média de pontos por jogo')
plt.xticks([i for i in range(0, len(per_career_points), 5)])
plt.bar([i for i in range(len(per_career_points))], sorted_per_career_points_avg['AVG'], color=colors)


legend_elements = [Line2D([0], [0], color='r', lw=4, label='Jordan'),
                   Line2D([0], [0], color='g', lw=4, label='Kobe'),
                   Line2D([0], [0], color='b', lw=4, label='Lebron')]

plt.legend(handles=legend_elements, loc=1)
plt.show()

# %%
top_5_avg_points_per_game_per_season = sorted_per_career_points_avg[:5].reset_index(drop=True)
top_5_avg_points_per_game_per_season
# Out:
#          AVG    name
# 0  37.085366  jordan
# 1  35.400000    kobe
# 2  34.975610  jordan
# 3  33.573171  jordan
# 4  32.576923  jordan

# %%
jordan_avg_pgps_pos = top_5_avg_points_per_game_per_season[top_5_avg_points_per_game_per_season.name == 'jordan'].index
kobe_avg_pgps_pos = top_5_avg_points_per_game_per_season[top_5_avg_points_per_game_per_season.name == 'kobe'].index
lebron_avg_pgps_pos = top_5_avg_points_per_game_per_season[top_5_avg_points_per_game_per_season.name == 'lebron'].index

# %%
jordan_stats_points += sum({i:top_5_points_mapping[i] for i in jordan_avg_pgps_pos}.values())
kobe_stats_points += sum({i:top_5_points_mapping[i] for i in kobe_avg_pgps_pos}.values())
lebron_stats_points += sum({i:top_5_points_mapping[i] for i in lebron_avg_pgps_pos}.values())

# %% [markdown]
# #### Assistências

# %% [markdown]
# ##### Total de assistências em temporada regular

# %%
jordan_total_ast = jordan_career['AST'].sum()
kobe_total_ast = kobe_career['AST'].sum()
lebron_total_ast = lebron_career['AST'].sum()

# %%
print('Total de assistências na carreira\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_ast,
    kobe_total_ast,
    lebron_total_ast,
))
# Out:
# Total de assistências na carreira
#
# Jordan: 5633
# Kobe: 6306
# Lebron: 9190

# %%
jordan_stats_points += 5
kobe_stats_points += 10
lebron_stats_points += 15

# %% [markdown]
# ##### Média de assistências por jogo

# %%
print('Média de assistências por jogo\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_ast/jordan_total_games,
    kobe_total_ast/kobe_total_games,
    lebron_total_ast/lebron_total_games,
))
# Out:
# Média de assistências por jogo
#
# Jordan: 5.254664179104478
# Kobe: 4.684992570579495
# Lebron: 7.369687249398557

# %%
jordan_stats_points += 10
kobe_stats_points += 5
lebron_stats_points += 15

# %% [markdown]
# ##### Média de assistências por temporada regular

# %%
print('Média de assistências por temporada\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_ast/jordan_total_seasons,
    kobe_total_ast/kobe_total_seasons,
    lebron_total_ast/lebron_total_seasons,
))
# Out:
# Média de assistências por temporada
#
# Jordan: 375.53333333333336
# Kobe: 315.3
# Lebron: 540.5882352941177

# %%
jordan_stats_points += 10
kobe_stats_points += 5
lebron_stats_points += 15

# %% [markdown]
# ##### Total de assistências por temporada

# %%
plt.figure(figsize=(10,10))
max_years = max([len(jordan_career), len(kobe_career), len(lebron_career)])
years = ['{}º ano'.format(i) for i in range(1, max_years+1)]
plt.xticks(list(range(max_years)),years, fontsize=14, rotation=90)

j, = plt.plot(jordan_career['AST'])
k, = plt.plot(kobe_career['AST'])
l, = plt.plot(lebron_career['AST'])
plt.title('Assistências por temporada')
plt.xlabel('Ano na carreira')
plt.ylabel('Assistências')
plt.legend([j,k,l], ('Jordan', 'Kobe', 'Lebron'))
plt.show()

# %%
jordan_career_ast = pd.DataFrame(jordan_career['AST'])
jordan_career_ast['name'] = 'jordan'
kobe_career_ast = pd.DataFrame(kobe_career['AST'])
kobe_career_ast['name'] = 'kobe'
lebron_career_ast = pd.DataFrame(lebron_career['AST'])
lebron_career_ast['name'] = 'lebron'
per_career_ast = pd.concat([jordan_career_ast, kobe_career_ast, lebron_career_ast])
sorted_per_career_ast =  per_career_ast.sort_values('AST', ascending=False)
colors = []
for _, i in sorted_per_career_ast.iterrows():
    if i['name'] == 'jordan':
        colors.append('r')
    elif i['name'] == 'kobe':
        colors.append('g')
    else:
        colors.append('b')
plt.figure(figsize=(10,10))
plt.title('Total de assistências por temporada')
plt.ylabel('Nº de assistências')
plt.xticks([i for i in range(0, len(per_career_ast), 5)])
plt.bar([i for i in range(len(per_career_ast))], sorted_per_career_ast['AST'], color=colors)


legend_elements = [Line2D([0], [0], color='r', lw=4, label='Jordan'),
                   Line2D([0], [0], color='g', lw=4, label='Kobe'),
                   Line2D([0], [0], color='b', lw=4, label='Lebron')]


plt.legend(handles=legend_elements, loc=1)
plt.show()

# %%
top_5_ast_per_season = sorted_per_career_ast[:5].reset_index(drop=True)
top_5_ast_per_season
# Out:
#    AST    name
# 0  747  lebron
# 1  651  lebron
# 2  650  jordan
# 3  646  lebron
# 4  587  lebron

# %%
jordan_aps_pos = top_5_ast_per_season[top_5_ast_per_season.name == 'jordan'].index
kobe_aps_pos = top_5_ast_per_season[top_5_ast_per_season.name == 'kobe'].index
lebron_aps_pos = top_5_ast_per_season[top_5_ast_per_season.name == 'lebron'].index

# %%
jordan_stats_points += sum({i:top_5_points_mapping[i] for i in jordan_aps_pos}.values())
kobe_stats_points += sum({i:top_5_points_mapping[i] for i in kobe_aps_pos}.values())
lebron_stats_points += sum({i:top_5_points_mapping[i] for i in lebron_aps_pos}.values())

# %% [markdown]
# ##### Média de assistências por jogo por temporada

# %%
plt.figure(figsize=(10,10))
max_years = max([len(jordan_career), len(kobe_career), len(lebron_career)])
years = ['{}º ano'.format(i) for i in range(1, max_years+1)]
plt.xticks(list(range(max_years)),years, fontsize=14, rotation=90)

j, = plt.plot(jordan_career['AST']/jordan_career['G'])
k, = plt.plot(kobe_career['AST']/kobe_career['G'])
l, = plt.plot(lebron_career['AST']/lebron_career['G'])
plt.title('Média de assistências por jogo por temporada')
plt.xlabel('Ano na carreira')
plt.ylabel('Média de assistências')
plt.legend([j,k,l], ('Jordan', 'Kobe', 'Lebron'))
plt.show()

# %%
jordan_career_ast_avg = pd.DataFrame({'AVG': jordan_career['AST']/jordan_career['G']})
jordan_career_ast_avg['name'] = 'jordan'
kobe_career_ast_avg = pd.DataFrame({'AVG':kobe_career['AST']/kobe_career['G']})
kobe_career_ast_avg['name'] = 'kobe'
lebron_career_ast_avg = pd.DataFrame({'AVG':lebron_career['AST']/lebron_career['G']})
lebron_career_ast_avg['name'] = 'lebron'
per_career_ast_avg = pd.concat([jordan_career_ast_avg, kobe_career_ast_avg, lebron_career_ast_avg])
sorted_per_career_ast_avg =  per_career_ast_avg.sort_values('AVG', ascending=False)
colors = []
for _, i in sorted_per_career_ast_avg.iterrows():
    if i['name'] == 'jordan':
        colors.append('r')
    elif i['name'] == 'kobe':
        colors.append('g')
    else:
        colors.append('b')
plt.figure(figsize=(10,10))
plt.title('Média de assistências por jogo por temporada')
plt.ylabel('Média de assistências por jogo')
plt.xticks([i for i in range(0, len(per_career_ast_avg), 5)])
plt.bar([i for i in range(len(per_career_ast_avg))], sorted_per_career_ast_avg['AVG'], color=colors)


legend_elements = [Line2D([0], [0], color='r', lw=4, label='Jordan'),
                   Line2D([0], [0], color='g', lw=4, label='Kobe'),
                   Line2D([0], [0], color='b', lw=4, label='Lebron')]

plt.legend(handles=legend_elements, loc=1)
plt.show()

# %%
top_5_avg_ast_per_game_per_season = sorted_per_career_ast_avg[:5].reset_index(drop=True)
top_5_avg_ast_per_game_per_season
# Out:
#          AVG    name
# 0  10.775510  lebron
# 1   9.109756  lebron
# 2   8.729730  lebron
# 3   8.565789  lebron
# 4   8.254545  lebron

# %%
jordan_avg_agps_pos = top_5_avg_ast_per_game_per_season[top_5_avg_ast_per_game_per_season.name == 'jordan'].index
kobe_avg_agps_pos = top_5_avg_ast_per_game_per_season[top_5_avg_ast_per_game_per_season.name == 'kobe'].index
lebron_avg_agps_pos = top_5_avg_ast_per_game_per_season[top_5_avg_ast_per_game_per_season.name == 'lebron'].index

# %%
jordan_stats_points += sum({i:top_5_points_mapping[i] for i in jordan_avg_agps_pos}.values())
kobe_stats_points += sum({i:top_5_points_mapping[i] for i in kobe_avg_agps_pos}.values())
lebron_stats_points += sum({i:top_5_points_mapping[i] for i in lebron_avg_agps_pos}.values())

# %% [markdown]
# #### Rebotes ofensivos

# %% [markdown]
# ##### Total de rebotes ofensivos em temporada regular

# %%
jordan_total_orb = jordan_career['ORB'].sum()
kobe_total_orb = kobe_career['ORB'].sum()
lebron_total_orb = lebron_career['ORB'].sum()

# %%
print('Total de rebotes ofensivos na carreira\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_orb,
    kobe_total_orb,
    lebron_total_orb,
))
# Out:
# Total de rebotes ofensivos na carreira
#
# Jordan: 1668
# Kobe: 1499
# Lebron: 1493

# %%
jordan_stats_points += 15
kobe_stats_points += 10
lebron_stats_points += 5

# %% [markdown]
# ##### Média de rebotes ofensivos por jogo

# %%
print('Média de rebotes ofensivos por jogo\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_orb/jordan_total_games,
    kobe_total_orb/kobe_total_games,
    lebron_total_orb/lebron_total_games,
))
# Out:
# Média de rebotes ofensivos por jogo
#
# Jordan: 1.5559701492537314
# Kobe: 1.1136701337295691
# Lebron: 1.1972734562951082

# %%
jordan_stats_points += 15
kobe_stats_points += 5
lebron_stats_points += 10

# %% [markdown]
# ##### Média de rebotes ofensivos por temporada regular

# %%
print('Média de rebotes ofensivos por temporada\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_orb/jordan_total_seasons,
    kobe_total_orb/kobe_total_seasons,
    lebron_total_orb/lebron_total_seasons,
))
# Out:
# Média de rebotes ofensivos por temporada
#
# Jordan: 111.2
# Kobe: 74.95
# Lebron: 87.82352941176471

# %%
jordan_stats_points += 15
kobe_stats_points += 5
lebron_stats_points += 10

# %% [markdown]
# ##### Total de rebotes ofensivos por temporada

# %%
plt.figure(figsize=(10,10))
max_years = max([len(jordan_career), len(kobe_career), len(lebron_career)])
years = ['{}º ano'.format(i) for i in range(1, max_years+1)]
plt.xticks(list(range(max_years)),years, fontsize=14, rotation=90)

j, = plt.plot(jordan_career['ORB'])
k, = plt.plot(kobe_career['ORB'])
l, = plt.plot(lebron_career['ORB'])
plt.title('Rebotes ofensivos por temporada')
plt.xlabel('Ano na carreira')
plt.ylabel('Rebotes ofensivos')
plt.legend([j,k,l], ('Jordan', 'Kobe', 'Lebron'))
plt.show()

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

jordan_career_orb = pd.DataFrame(jordan_career['ORB'])
jordan_career_orb['name'] = 'jordan'
kobe_career_orb = pd.DataFrame(kobe_career['ORB'])
kobe_career_orb['name'] = 'kobe'
lebron_career_orb = pd.DataFrame(lebron_career['ORB'])
lebron_career_orb['name'] = 'lebron'
per_career_orb = pd.concat([jordan_career_orb, kobe_career_orb, lebron_career_orb])
sorted_per_career_orb =  per_career_orb.sort_values('ORB', ascending=False)
colors = []
for _, i in sorted_per_career_orb.iterrows():
    if i['name'] == 'jordan':
        colors.append('r')
    elif i['name'] == 'kobe':
        colors.append('g')
    else:
        colors.append('b')
plt.figure(figsize=(10,10))
plt.title('Total de rebotes por temporada')
plt.ylabel('Nº de rebotes')
plt.xticks([i for i in range(0, len(per_career_orb), 5)])
plt.bar([i for i in range(len(per_career_orb))], sorted_per_career_orb['ORB'], color=colors)


legend_elements = [Line2D([0], [0], color='r', lw=4, label='Jordan'),
                   Line2D([0], [0], color='g', lw=4, label='Kobe'),
                   Line2D([0], [0], color='b', lw=4, label='Lebron')]

plt.legend(handles=legend_elements, loc=1)
plt.show()

# %%
top_5_orb_per_season = sorted_per_career_orb[:5].reset_index(drop=True)
top_5_orb_per_season
# Out:
#    ORB    name
# 0  167  jordan
# 1  166  jordan
# 2  149  jordan
# 3  148  jordan
# 4  143  jordan

# %%
jordan_orbps_pos = top_5_orb_per_season[top_5_orb_per_season.name == 'jordan'].index
kobe_orbps_pos = top_5_orb_per_season[top_5_orb_per_season.name == 'kobe'].index
lebron_orbps_pos = top_5_orb_per_season[top_5_orb_per_season.name == 'lebron'].index

# %%
jordan_stats_points += sum({i:top_5_points_mapping[i] for i in jordan_orbps_pos}.values())
kobe_stats_points += sum({i:top_5_points_mapping[i] for i in kobe_orbps_pos}.values())
lebron_stats_points += sum({i:top_5_points_mapping[i] for i in lebron_orbps_pos}.values())

# %% [markdown]
# ##### Média de rebotes ofensivos por jogo por temporada

# %%
plt.figure(figsize=(10,10))
max_years = max([len(jordan_career), len(kobe_career), len(lebron_career)])
years = ['{}º ano'.format(i) for i in range(1, max_years+1)]
plt.xticks(list(range(max_years)),years, fontsize=14, rotation=90)

j, = plt.plot(jordan_career['ORB']/jordan_career['G'])
k, = plt.plot(kobe_career['ORB']/kobe_career['G'])
l, = plt.plot(lebron_career['ORB']/lebron_career['G'])
plt.title('Média de rebotes ofensivos por jogo por temporada')
plt.xlabel('Ano na carreira')
plt.ylabel('Média de rebotes ofensivos')
plt.legend([j,k,l], ('Jordan', 'Kobe', 'Lebron'))
plt.show()

# %%
jordan_career_orb_avg = pd.DataFrame({'AVG': jordan_career['ORB']/jordan_career['G']})
jordan_career_orb_avg['name'] = 'jordan'
kobe_career_orb_avg = pd.DataFrame({'AVG':kobe_career['ORB']/kobe_career['G']})
kobe_career_orb_avg['name'] = 'kobe'
lebron_career_orb_avg = pd.DataFrame({'AVG':lebron_career['ORB']/lebron_career['G']})
lebron_career_orb_avg['name'] = 'lebron'
per_career_orb_avg = pd.concat([jordan_career_orb_avg, kobe_career_orb_avg, lebron_career_orb_avg])
sorted_per_career_orb_avg =  per_career_orb_avg.sort_values('AVG', ascending=False)
colors = []
for _, i in sorted_per_career_orb_avg.iterrows():
    if i['name'] == 'jordan':
        colors.append('r')
    elif i['name'] == 'kobe':
        colors.append('g')
    else:
        colors.append('b')
plt.figure(figsize=(10,10))
plt.title('Média de rebotes ofensivos por jogo por temporada')
plt.ylabel('Média de rebotes ofensivos')
plt.xticks([i for i in range(0, len(per_career_orb_avg), 5)])
plt.bar([i for i in range(len(per_career_orb_avg))], sorted_per_career_orb_avg['AVG'], color=colors)


legend_elements = [Line2D([0], [0], color='r', lw=4, label='Jordan'),
                   Line2D([0], [0], color='g', lw=4, label='Kobe'),
                   Line2D([0], [0], color='b', lw=4, label='Lebron')]


plt.legend(handles=legend_elements, loc=1)
plt.show()

# %%
top_5_avg_orb_per_game_per_season = sorted_per_career_orb_avg[:5].reset_index(drop=True)
top_5_avg_orb_per_game_per_season
# Out:
#         AVG    name
# 0  2.036585  jordan
# 1  2.024390  jordan
# 2  1.839506  jordan
# 3  1.804878  jordan
# 4  1.773333  lebron

# %%
jordan_avg_orbps_pos = top_5_avg_orb_per_game_per_season[top_5_avg_orb_per_game_per_season.name == 'jordan'].index
kobe_avg_orbps_pos = top_5_avg_orb_per_game_per_season[top_5_avg_orb_per_game_per_season.name == 'kobe'].index
lebron_avg_orbps_pos = top_5_avg_orb_per_game_per_season[top_5_avg_orb_per_game_per_season.name == 'lebron'].index

# %%
jordan_stats_points += sum({i:top_5_points_mapping[i] for i in jordan_avg_orbps_pos}.values())
kobe_stats_points += sum({i:top_5_points_mapping[i] for i in kobe_avg_orbps_pos}.values())
lebron_stats_points += sum({i:top_5_points_mapping[i] for i in lebron_avg_orbps_pos}.values())

# %% [markdown]
# #### Rebotes defensivos

# %% [markdown]
# ##### Total de rebotes defensivos em temporada regular

# %%
jordan_total_drb = jordan_career['DRB'].sum()
kobe_total_drb = kobe_career['DRB'].sum()
lebron_total_drb = lebron_career['DRB'].sum()

# %%
print('Total de rebotes defensivos na carreira\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_drb,
    kobe_total_drb,
    lebron_total_drb,
))
# Out:
# Total de rebotes defensivos na carreira
#
# Jordan: 5004
# Kobe: 5548
# Lebron: 7766

# %%
jordan_stats_points += 5
kobe_stats_points += 10
lebron_stats_points += 15

# %% [markdown]
# ##### Média de rebotes defensivos por jogo

# %%
print('Média de rebotes defensivos por jogo\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_drb/jordan_total_games,
    kobe_total_drb/kobe_total_games,
    lebron_total_drb/lebron_total_games,
))
# Out:
# Média de rebotes defensivos por jogo
#
# Jordan: 4.667910447761194
# Kobe: 4.121842496285289
# Lebron: 6.2277465918203685

# %%
jordan_stats_points += 10
kobe_stats_points += 5
lebron_stats_points += 15

# %% [markdown]
# ##### Média de rebotes defensivos por temporada regular

# %%
print('Média de rebotes defensivos por temporada\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_drb/jordan_total_seasons,
    kobe_total_drb/kobe_total_seasons,
    lebron_total_drb/lebron_total_seasons,
))
# Out:
# Média de rebotes defensivos por temporada
#
# Jordan: 333.6
# Kobe: 277.4
# Lebron: 456.8235294117647

# %%
jordan_stats_points += 10
kobe_stats_points += 5
lebron_stats_points += 15

# %% [markdown]
# ##### Total de rebotes defensivos por temporada

# %%
plt.figure(figsize=(10,10))
max_years = max([len(jordan_career), len(kobe_career), len(lebron_career)])
years = ['{}º ano'.format(i) for i in range(1, max_years+1)]
plt.xticks(list(range(max_years)),years, fontsize=14, rotation=90)

j, = plt.plot(jordan_career['DRB'])
k, = plt.plot(kobe_career['DRB'])
l, = plt.plot(lebron_career['DRB'])
plt.title('Rebotes defensivos por temporada')
plt.xlabel('Ano na carreira')
plt.ylabel('Rebotes defensivos')
plt.legend([j,k,l], ('Jordan', 'Kobe', 'Lebron'))
plt.show()

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

jordan_career_drb = pd.DataFrame(jordan_career['DRB'])
jordan_career_drb['name'] = 'jordan'
kobe_career_drb = pd.DataFrame(kobe_career['DRB'])
kobe_career_drb['name'] = 'kobe'
lebron_career_drb = pd.DataFrame(lebron_career['DRB'])
lebron_career_drb['name'] = 'lebron'
per_career_drb = pd.concat([jordan_career_drb, kobe_career_drb, lebron_career_drb])
sorted_per_career_drb =  per_career_drb.sort_values('DRB', ascending=False)
colors = []
for _, i in sorted_per_career_drb.iterrows():
    if i['name'] == 'jordan':
        colors.append('r')
    elif i['name'] == 'kobe':
        colors.append('g')
    else:
        colors.append('b')
plt.figure(figsize=(10,10))
plt.title('Total de rebotes defensivos por temporada')
plt.ylabel('Nº de rebotes')
plt.xticks([i for i in range(0, len(per_career_drb), 5)])
plt.bar([i for i in range(len(per_career_drb))], sorted_per_career_drb['DRB'], color=colors)


legend_elements = [Line2D([0], [0], color='r', lw=4, label='Jordan'),
                   Line2D([0], [0], color='g', lw=4, label='Kobe'),
                   Line2D([0], [0], color='b', lw=4, label='Lebron')]

# Create the figure
plt.legend(handles=legend_elements, loc=1)
plt.show()

# %%
top_5_drb_per_season = sorted_per_career_drb[:5].reset_index(drop=True)
top_5_drb_per_season
# Out:
#    DRB    name
# 0  612  lebron
# 1  542  lebron
# 2  513  lebron
# 3  510  lebron
# 4  507  lebron

# %%
jordan_drbps_pos = top_5_drb_per_season[top_5_drb_per_season.name == 'jordan'].index
kobe_drbps_pos = top_5_drb_per_season[top_5_drb_per_season.name == 'kobe'].index
lebron_drbps_pos = top_5_drb_per_season[top_5_drb_per_season.name == 'lebron'].index

# %%
jordan_stats_points += sum({i:top_5_points_mapping[i] for i in jordan_drbps_pos}.values())
kobe_stats_points += sum({i:top_5_points_mapping[i] for i in kobe_drbps_pos}.values())
lebron_stats_points += sum({i:top_5_points_mapping[i] for i in lebron_drbps_pos}.values())

# %% [markdown]
# ##### Média de rebotes defensivos por jogo por temporada

# %%
plt.figure(figsize=(10,10))
max_years = max([len(jordan_career), len(kobe_career), len(lebron_career)])
years = ['{}º ano'.format(i) for i in range(1, max_years+1)]
plt.xticks(list(range(max_years)),years, fontsize=14, rotation=90)

j, = plt.plot(jordan_career['DRB']/jordan_career['G'])
k, = plt.plot(kobe_career['DRB']/kobe_career['G'])
l, = plt.plot(lebron_career['DRB']/lebron_career['G'])
plt.title('Média de rebotes defensivos por jogo por temporada')
plt.xlabel('Ano na carreira')
plt.ylabel('Média de rebotes defensivos')
plt.legend([j,k,l], ('Jordan', 'Kobe', 'Lebron'))
plt.show()

# %%
jordan_career_drb_avg = pd.DataFrame({'AVG': jordan_career['DRB']/jordan_career['G']})
jordan_career_drb_avg['name'] = 'jordan'
kobe_career_drb_avg = pd.DataFrame({'AVG':kobe_career['DRB']/kobe_career['G']})
kobe_career_drb_avg['name'] = 'kobe'
lebron_career_drb_avg = pd.DataFrame({'AVG':lebron_career['DRB']/lebron_career['G']})
lebron_career_drb_avg['name'] = 'lebron'
per_career_drb_avg = pd.concat([jordan_career_drb_avg, kobe_career_drb_avg, lebron_career_drb_avg])
sorted_per_career_drb_avg =  per_career_drb_avg.sort_values('AVG', ascending=False)
colors = []
for _, i in sorted_per_career_drb_avg.iterrows():
    if i['name'] == 'jordan':
        colors.append('r')
    elif i['name'] == 'kobe':
        colors.append('g')
    else:
        colors.append('b')
plt.figure(figsize=(10,10))
plt.title('Média de rebotes ofensivos por jogo por temporada')
plt.ylabel('Média de rebotes ofensivos')
plt.xticks([i for i in range(0, len(per_career_drb_avg), 5)])
plt.bar([i for i in range(len(per_career_drb_avg))], sorted_per_career_drb_avg['AVG'], color=colors)


legend_elements = [Line2D([0], [0], color='r', lw=4, label='Jordan'),
                   Line2D([0], [0], color='g', lw=4, label='Kobe'),
                   Line2D([0], [0], color='b', lw=4, label='Lebron')]


plt.legend(handles=legend_elements, loc=1)
plt.show()

# %%
top_5_avg_drb_per_game_per_season = sorted_per_career_drb_avg[:5].reset_index(drop=True)
top_5_avg_drb_per_game_per_season
# Out:
#         AVG    name
# 0  7.463415  lebron
# 1  7.418182  lebron
# 2  7.324324  lebron
# 3  6.750000  lebron
# 4  6.714286  lebron

# %%
jordan_avg_drbps_pos = top_5_avg_drb_per_game_per_season[top_5_avg_drb_per_game_per_season.name == 'jordan'].index
kobe_avg_drbps_pos = top_5_avg_drb_per_game_per_season[top_5_avg_drb_per_game_per_season.name == 'kobe'].index
lebron_avg_drbps_pos = top_5_avg_drb_per_game_per_season[top_5_avg_drb_per_game_per_season.name == 'lebron'].index

# %%
jordan_stats_points += sum({i:top_5_points_mapping[i] for i in jordan_avg_drbps_pos}.values())
kobe_stats_points += sum({i:top_5_points_mapping[i] for i in kobe_avg_drbps_pos}.values())
lebron_stats_points += sum({i:top_5_points_mapping[i] for i in lebron_avg_drbps_pos}.values())

# %% [markdown]
# #### Turnovers

# %% [markdown]
# ##### Total de turnovers em temporada regular

# %%
jordan_total_tov = jordan_career['TOV'].sum()
kobe_total_tov = kobe_career['TOV'].sum()
lebron_total_tov = lebron_career['TOV'].sum()

# %%
print('Total de turnovers na carreira\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_tov,
    kobe_total_tov,
    lebron_total_tov,
))
# Out:
# Total de turnovers na carreira
#
# Jordan: 2924
# Kobe: 4010
# Lebron: 4358

# %%
jordan_stats_points += 15
kobe_stats_points += 10
lebron_stats_points += 5

# %% [markdown]
# ##### Média de turnovers por jogo

# %%
print('Média de turnovers por jogo\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_tov/jordan_total_games,
    kobe_total_tov/kobe_total_games,
    lebron_total_tov/lebron_total_games,
))
# Out:
# Média de turnovers por jogo
#
# Jordan: 2.7276119402985075
# Kobe: 2.9791976225854384
# Lebron: 3.494787489975942

# %%
jordan_stats_points += 15
kobe_stats_points += 10
lebron_stats_points += 5

# %% [markdown]
# ##### Média de turnovers por temporada regular

# %%
print('Média de turnoves por temporada\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(
    jordan_total_tov/jordan_total_seasons,
    kobe_total_tov/kobe_total_seasons,
    lebron_total_tov/lebron_total_seasons,
))
# Out:
# Média de turnoves por temporada
#
# Jordan: 194.93333333333334
# Kobe: 200.5
# Lebron: 256.3529411764706

# %%
jordan_stats_points += 15
kobe_stats_points += 10
lebron_stats_points += 5

# %% [markdown]
# ##### Total de turnovers por temporada

# %%
plt.figure(figsize=(10,10))
max_years = max([len(jordan_career), len(kobe_career), len(lebron_career)])
years = ['{}º ano'.format(i) for i in range(1, max_years+1)]
plt.xticks(list(range(max_years)),years, fontsize=14, rotation=90)

j, = plt.plot(jordan_career['TOV'])
k, = plt.plot(kobe_career['TOV'])
l, = plt.plot(lebron_career['TOV'])
plt.title('Turnovers por temporada')
plt.xlabel('Ano na carreira')
plt.ylabel('Turnovers')
plt.legend([j,k,l], ('Jordan', 'Kobe', 'Lebron'))
plt.show()

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

jordan_career_tov = pd.DataFrame(jordan_career['TOV'])
jordan_career_tov['name'] = 'jordan'
kobe_career_tov = pd.DataFrame(kobe_career['TOV'])
kobe_career_tov['name'] = 'kobe'
lebron_career_tov = pd.DataFrame(lebron_career['TOV'])
lebron_career_tov['name'] = 'lebron'
per_career_tov = pd.concat([jordan_career_tov, kobe_career_tov, lebron_career_tov])
sorted_per_career_tov =  per_career_tov.sort_values('TOV')
colors = []
for _, i in sorted_per_career_tov.iterrows():
    if i['name'] == 'jordan':
        colors.append('r')
    elif i['name'] == 'kobe':
        colors.append('g')
    else:
        colors.append('b')
plt.figure(figsize=(10,10))
plt.title('Total de turnovers por temporada')
plt.ylabel('Nº de turnovers')
plt.xticks([i for i in range(0, len(per_career_tov), 5)])
plt.bar([i for i in range(len(per_career_tov))], sorted_per_career_tov['TOV'], color=colors)


legend_elements = [Line2D([0], [0], color='r', lw=4, label='Jordan'),
                   Line2D([0], [0], color='g', lw=4, label='Kobe'),
                   Line2D([0], [0], color='b', lw=4, label='Lebron')]


plt.legend(handles=legend_elements, loc=1)
plt.show()

# %%
top_5_less_tov_per_season = sorted_per_career_tov[:5].reset_index(drop=True)
top_5_less_tov_per_season
# Out:
#    TOV    name
# 0   34    kobe
# 1   35  jordan
# 2   45  jordan
# 3  112    kobe
# 4  128    kobe

# %%
jordan_ltovps_pos = top_5_less_tov_per_season[top_5_less_tov_per_season.name == 'jordan'].index
kobe_ltovps_pos = top_5_less_tov_per_season[top_5_less_tov_per_season.name == 'kobe'].index
lebron_ltovps_pos = top_5_less_tov_per_season[top_5_less_tov_per_season.name == 'lebron'].index

# %%
jordan_stats_points += sum({i:top_5_points_mapping[i] for i in jordan_ltovps_pos}.values())
kobe_stats_points += sum({i:top_5_points_mapping[i] for i in kobe_ltovps_pos}.values())
lebron_stats_points += sum({i:top_5_points_mapping[i] for i in lebron_ltovps_pos}.values())

# %% [markdown]
# ##### Média de turnovers por jogo por temporada

# %%
plt.figure(figsize=(10,10))
max_years = max([len(jordan_career), len(kobe_career), len(lebron_career)])
years = ['{}º ano'.format(i) for i in range(1, max_years+1)]
plt.xticks(list(range(max_years)),years, fontsize=14, rotation=90)

j, = plt.plot(jordan_career['TOV']/jordan_career['G'])
k, = plt.plot(kobe_career['TOV']/kobe_career['G'])
l, = plt.plot(lebron_career['TOV']/lebron_career['G'])
plt.title('Média de turnovers por jogo por temporada')
plt.xlabel('Ano na carreira')
plt.ylabel('Média de turnovers')
plt.legend([j,k,l], ('Jordan', 'Kobe', 'Lebron'))
plt.show()

# %%
jordan_career_tov_avg = pd.DataFrame({'AVG': jordan_career['TOV']/jordan_career['G']})
jordan_career_tov_avg['name'] = 'jordan'
kobe_career_tov_avg = pd.DataFrame({'AVG':kobe_career['TOV']/kobe_career['G']})
kobe_career_tov_avg['name'] = 'kobe'
lebron_career_tov_avg = pd.DataFrame({'AVG':lebron_career['TOV']/lebron_career['G']})
lebron_career_tov_avg['name'] = 'lebron'
per_career_tov_avg = pd.concat([jordan_career_tov_avg, kobe_career_tov_avg, lebron_career_tov_avg])
sorted_per_career_tov_avg =  per_career_tov_avg.sort_values('AVG')
colors = []
for _, i in sorted_per_career_tov_avg.iterrows():
    if i['name'] == 'jordan':
        colors.append('r')
    elif i['name'] == 'kobe':
        colors.append('g')
    else:
        colors.append('b')
plt.figure(figsize=(10,10))
plt.title('Média de turnovers por jogo por temporada')
plt.ylabel('Média de turnovers')
plt.xticks([i for i in range(0, len(per_career_tov_avg), 5)])
plt.bar([i for i in range(len(per_career_tov_avg))], sorted_per_career_tov_avg['AVG'], color=colors)


legend_elements = [Line2D([0], [0], color='r', lw=4, label='Jordan'),
                   Line2D([0], [0], color='g', lw=4, label='Kobe'),
                   Line2D([0], [0], color='b', lw=4, label='Lebron')]

plt.legend(handles=legend_elements, loc=1)
plt.show()

# %%
top_5_less_avg_tov_per_game_per_season = sorted_per_career_tov_avg[:5].reset_index(drop=True)
top_5_less_avg_tov_per_game_per_season
# Out:
#         AVG    name
# 0  1.577465    kobe
# 1  1.954545    kobe
# 2  1.987342    kobe
# 3  2.024390  jordan
# 4  2.058824  jordan

# %%
jordan_avg_ltgps_pos = top_5_less_avg_tov_per_game_per_season[top_5_less_avg_tov_per_game_per_season.name == 'jordan'].index
kobe_avg_ltgps_pos = top_5_less_avg_tov_per_game_per_season[top_5_less_avg_tov_per_game_per_season.name == 'kobe'].index
lebron_avg_ltgps_pos = top_5_less_avg_tov_per_game_per_season[top_5_less_avg_tov_per_game_per_season.name == 'lebron'].index

# %%
jordan_stats_points += sum({i:top_5_points_mapping[i] for i in jordan_avg_ltgps_pos}.values())
kobe_stats_points += sum({i:top_5_points_mapping[i] for i in kobe_avg_ltgps_pos}.values())
lebron_stats_points += sum({i:top_5_points_mapping[i] for i in lebron_avg_ltgps_pos}.values())

# %% [markdown]
# ### Resultado final

# %%
jordan_titles_points, kobe_titles_points, lebron_titles_points
# Out:
# (17, 14, 14)

# %%
jordan_ind_awards_points, kobe_ind_awards_points, lebron_ind_awards_points
# Out:
# (10, 10, 10)

# %%
jordan_stats_points, kobe_stats_points, lebron_stats_points
# Out:
# (240, 137, 223)

# %%
jordan_total = jordan_titles_points + jordan_ind_awards_points + jordan_stats_points/5
kobe_total = kobe_titles_points + kobe_ind_awards_points + kobe_stats_points/5
lebron_total = lebron_titles_points + lebron_ind_awards_points + lebron_stats_points/5

# %%
print('Pontuação final\n')
print('Jordan: {}\nKobe: {}\nLebron: {}'.format(jordan_total, kobe_total, lebron_total))
# Out:
# Pontuação final
#
# Jordan: 75.0
# Kobe: 51.4
# Lebron: 68.6

# %% [markdown]
# ### Conclusão
#
# Usando exclusivamente os critérios explicados acima em cada seção, Michael Jordan pode ser considerado o maior dentre os 3 jogadores. Apesar dessa ser uma análise simples e não envolver outros jogadores fora os três, ela mostra que Michael, além de ter números superiores em diversos critérios, manteve uma consistência grande ao longo dos anos. Outro ponto que engrandece ainda mais seus feitos é o fato dele ser o jogador entre os três com menos jogos (quase 300 a menos que Kobe e 200 a menos que Lebron) e menos temporadas disputadas.
#
# Para efeito de comparação, dos totais e das médias (por jogo e temporada) avaliadas para as 5 estastísticas, totalizando 15 medidas, ele fica em primeiro em 8. Em outras 4, em segundo. Nas três estatíticas que Jordan fica em terceiro (total de pontos feitos, total de assistências e total de rebotes defensivos), ele é 5º, 45º e 79º, respectivamente, de toda história na NBA.
#
# Fora isso, nas 3 temporadas em que ele está bem abaixo dos números apresentados por Kobe e James, bastante jogos não contaram com sua presença. Na segunda temporada de sua carreira (1985-1986), ele perdeu 64 jogos, por conta de um pé quebrado no terceiro jogo da temporada; no que seria sua décima temporada (1993-1994) não jogou pois antes de seu início, anunciou sua primeira aposentadoria, bastante influenciada pela morte de seu pai, e passou o ano jogando beisebol. Ao retornar para NBA na temporara 1994-1995, Jordan jogou apenas 17 jogos. Porém marcou 457 pontos, uma média de quase 27 pontos por jogo; já em seu penúltimo ano na liga, jogou apenas 60 jogos por conta de um problema no joelho direito e marcou uma média de 23 pontos por jogo, a terceira menor de sua carreira.
